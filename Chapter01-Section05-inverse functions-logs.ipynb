# %% [markdown]
# ### Chapter 1, Section 5: This lesson deals with exponential inverse functions.
# - Problems: Paper (27, 32, 39, 42, 43, 45, 59).
# - Problems: Jupyter (27, 32). 27 is done below.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym
# Define the domain for each function
x_exp = np.linspace(0.1, 3, 100)   
y_exp = np.exp(1- x_exp) 

x_inv = np.linspace(0.1, 3, 100) 
y_inv = 1 - np.log(x_inv)  

# Plotting
plt.plot(x_exp, y_exp, label="$f(x) = e[1-x]$", color='blue')
plt.plot(x_inv, y_inv, label="$f⁻¹(x) = 1 - ln(x)", color='green')
plt.plot(x_exp, x_exp, label="y = x (line of symmetry)", linestyle='--', color='gray')

plt.title("Exponential Function and Its Inverse")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.axis('equal')  # Keeps symmetry across y=x
plt.show()

# %%
sym.init_printing
x, y = sym.symbols('x y')
f = (1+ sym.exp(-x))
eq= sym.Eq(y, f)
inverse_solved = sym.solve(eq, x)[0]
print ("equation:")
display(eq)
print ("inverse:")
display (inverse_solved)
# Out:
# equation:
# Eq(y, 1 + exp(-x))
# inverse:
# log(1/(y - 1))

# %%
inverse_solved = sym.solve(eq, x)[0]

# %%
f_lambdified = sym.lambdify(x, f, modules=['numpy'])
inv_lambdified = sym.lambdify(y, inverse_solved, 'numpy')

# %%
x_vals = np.linspace(0.5, 20, 400)
y_vals = f_lambdified(x_vals)
inv_vals = inv_lambdified(y_vals)

# %%
plt.plot(x_vals, y_vals, color='blue')
plt.plot(y_vals, inv_vals, color='red')

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym

x = np.linspace(-2, 5, 400)

g_vals = 1 + np.exp(-x)
x_inv2 = np.linspace(1.01, np.max(g_vals), 400)   # x values for inverse (must be > 1)
g_inv_vals = -np.log(x_inv2 - 1)

plt.figure(figsize=(8, 6))

plt.plot(x, f1_vals, label=r'$f(x)=e^{1-x}$', color='blue')
plt.plot(x, g_vals, label=r'$g(x)=1+e^{-x}$', color='red')

# Plot inverses (plotted as x vs inverse(x) using valid domains)
plt.plot(x_inv1, f1_inv_vals, label=r'$f^{-1}(x)=1-\ln(x)\ (x>0)$', color='green')
plt.plot(x_inv2, g_inv_vals, label=r'$g^{-1}(x)=-\ln(x-1)\ (x>1)$', color='purple')

# Diagonal y=x for symmetry
diag = np.linspace(-2, 5, 200)
plt.plot(diag, diag, linestyle='--', color='gray', label='y = x')

plt.title("Exponential Functions and Their Inverses")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.axis('equal')
plt.xlim(-2, 5)
plt.ylim(-2, 8)
plt.show()
