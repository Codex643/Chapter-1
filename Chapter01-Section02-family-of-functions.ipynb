# %% [markdown]
# ### Chapter 1, Section 2: Family of Functions
# - This section introduces you to some common functions (see page 32). We will use Jupyter to plot these functions.
# - The example below is for reciprocal functions. Repeat this process for the other families of functions listed on page 32 (e.g., linear, root, exponential, logarithmic, and trigonometric).
# - Plot at least five graphs for each function type, and feel free to be creative.
# - When analyzing the behavior of functions, remember that the domain is important.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - Set the Domain: the x values from -a to -a with n values

# %%
a = 1
npoints = 200
x = np.linspace(-a, a, npoints)

# %%
#print(x) #Remove the first hashtag to see the values of x.

# %%
y0 = x**(-0)
y1 = x**(-1)
y2 = x**(-2)
y3 = x**(-3)
y4 = x**(-4)

# %%
#print(y1) #Remove the first hashtag to see the values of y1.
#print(y4) #Remove the first hashtag to see the values of y2.

# %% [markdown]
# - Plot the functions on the domain [-a,a]
# - Add a title, labels, grid, labels, and legend

# %%
plt.plot(x, y0, label=r'$x^-0$', color='black')
plt.plot(x, y1, label=r'$x^-1$', color='black')
plt.plot(x, y2, label=r'$x^-2$', color='black')
plt.plot(x, y3, label=r'$x^-3$', color='black')
plt.plot(x, y4, label=r'$x^-4$', color='black')
plt.title('Reciprocal Functions')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ##### Reciprocal Functions change rapidly with power. Replot these individually and see that range change.

# %%
plt.plot(x, y0, label=r'$x^-0$', color='black')
plt.title('Reciprocal Functions')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.plot(x, y1, label=r'$x^-1$', color='black')
plt.title('Reciprocal Functions')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.plot(x, y2, label=r'$x^-2$', color='black')
plt.title('Reciprocal Functions')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.plot(x, y3, label=r'$x^-3$', color='black')
plt.title('Reciprocal Functions')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.plot(x, y4, label=r'$x^-4$', color='black')
plt.title('Reciprocal Functions')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.show()

# %%
a = 2
npoints =100
x = np.linspace(-a,a, npoints)

# %%
y0 = 4*x-2
y1 = 5*x-2
y2 = 6*x-2
y3 = 7*x-2
y4 = 8*x-2

# %%
plt.plot(x, y0, label=r'$4x-2x$', color='green')
plt.plot(x, y1, label=r'$5x-2$', color='purple')
plt.plot(x, y2, label=r'$6x-2$', color='blue')
plt.plot(x, y3, label=r'$7x-2$', color='red')
plt.plot(x, y4, label=r'$8x-2$', color='orange')
plt.title('Linear Functions')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.show()

# %%
a = 1
npoints = 200
x = np.linspace(-a, a, npoints)

# %%
y0 = x**1
y1 = x**6
y2 = x**7
y3 = x**500
y4 = x**15

# %%
plt.plot(x, y0, label=r'$x1$', color='green')
plt.plot(x, y1, label=r'$5x-2$', color='purple')
plt.plot(x, y2, label=r'$6x-2$', color='blue')
plt.plot(x, y3, label=r'$7x-2$', color='red')
plt.plot(x, y4, label=r'$8x-2$', color='orange')
plt.title('Power Functions')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.show()

# %%
a = 1
npoints = 200
x = np.linspace(-a, a, npoints)

# %%
y1 = np.sqrt(x)         # Square root
y2 = np.cbrt(x)         # Cube root
y3 = x**(1/4)           # Fourth root
y4 = x**(1/5)           # Fifth root
# Out:
# /var/folders/nn/8jf4swm1577f6rkhg518jnr40000gn/T/ipykernel_6149/3165102348.py:1: RuntimeWarning: invalid value encountered in sqrt
#   y1 = np.sqrt(x)         # Square root
# /var/folders/nn/8jf4swm1577f6rkhg518jnr40000gn/T/ipykernel_6149/3165102348.py:3: RuntimeWarning: invalid value encountered in power
#   y3 = x**(1/4)           # Fourth root
# /var/folders/nn/8jf4swm1577f6rkhg518jnr40000gn/T/ipykernel_6149/3165102348.py:4: RuntimeWarning: invalid value encountered in power
#   y4 = x**(1/5)           # Fifth root

# %%
plt.plot(x, y1, label='sqrt(x)', color='blue')
plt.plot(x, y2, label='cbrt(x)', color='green')
plt.plot(x, y3, label='x^(1/4)', color='red')
plt.plot(x, y4, label='x^(1/5)', color='orange')
plt.title('Root Functions')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.show()

# %%
x = np.linspace(-10, 10, 100)
y = 1 / x

# %%
plt.plot(x, y, label='f(x) = 1/x', color='purple')
plt.title('Reciprocal Function')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.ylim(-10, 10)  # Limit y-axis for better visualization
plt.show()

# %%
x = np.linspace(0.01, 4, 200)  # Avoid zero for log

# %%
y_exp1 = np.exp(x)         # Exponential: e^x
y_exp2 = 2**x              # Exponential: 2^x
y_exp3 = 0.5**x            # Exponential: 0.5^x

y_log1 = np.log(x)         # Natural log: ln(x)
y_log2 = np.log2(x)        # Log base 2
y_log3 = np.log10(x)       # Log base 10

# %%
plt.plot(x, y_exp1, label='e^x', color='blue')
plt.plot(x, y_exp2, label='2^x', color='green')
plt.plot(x, y_exp3, label='0.5^x', color='red')
plt.plot(x, y_log1, label='ln(x)', color='purple')
plt.plot(x, y_log2, label='log2(x)', color='orange')
plt.plot(x, y_log3, label='log10(x)', color='brown')
plt.title('Exponential and Logarithmic Functions')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.show()
